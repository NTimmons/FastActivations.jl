# %%
include("../src/ActivationsHeader.jl");

# %%
using Plots
using Flux

# %%
println("Sigmoid Functions")
println("Sigmoid = $(sigmoid(1.0))")
for f in FastActivations.SigmoidApproximations
    println("Value at 1.0 = $(f):$(f(1.0))") 
end

println()
println("Tanh Functions")
println("Tanh = $(tanh(1.0))")
for f in FastActivations.TanhApproximations
    println("Value at 1.0 = $(f):$(f(1.0))") 
end
# Out:
# Sigmoid Functions
# Sigmoid = 0.7310585786300049
# Value at 1.0 = sigmoidFastExp1:1.0
# Value at 1.0 = sigmoidFastExp2:0.9411764705882353
# Value at 1.0 = sigmoidFastExp4:0.7596439169139466
# Value at 1.0 = sigmoidFastExp8:0.7442641889587787
# Value at 1.0 = sigmoidFastExp16:0.7374228130632045
# Value at 1.0 = sigmoidFastExp32:0.7341845869898578
# Value at 1.0 = sigmoidFastExp64:0.7326079651620879
# Value at 1.0 = sigmoidFastExp128:0.7318299168324885
# Value at 1.0 = sigmoidFastExp256:0.7314434150230931
# Value at 1.0 = sigmoidFastExp512:0.7312507893999406
# Value at 1.0 = sigmoidFastExp1024:0.731154632251705
# Value at 1.0 = sigmoidFastExp2048:0.7311065925116854
# Value at 1.0 = sigmoidFastExp4096:0.7310825823399995
# Value at 1.0 = sigmoidFastExp8192:0.7310705796774776
# Value at 1.0 = sigmoidTaylor7:0.725818166444267
# Value at 1.0 = sigmoidTaylor9:0.7296324295521089
# Value at 1.0 = sigmoidTaylor11:0.7307562637199326
# Value at 1.0 = sigmoidPate33:0.7300703429688263
# Value at 1.0 = sigmoidPate34:0.7310601930327103
# Value at 1.0 = sigmoidPate44:0.7310327273513118
# Value at 1.0 = sigmoidPate45:0.7310608256199298
# Value at 1.0 = sigmoidPate55:0.7310582293642213
#
# Tanh Functions
# Tanh = 0.7615941559557649
# Value at 1.0 = Serpentine:0.8
# Value at 1.0 = SerpentineClamp:0.8
# Value at 1.0 = tanhFrac1:0.5
# Value at 1.0 = tanhFrac2:0.8
# Value at 1.0 = tanhFrac3:0.76
# Value at 1.0 = tanhFrac4:0.7616279069767442
# Value at 1.0 = tanhFrac5:0.7615937295885042
# Value at 1.0 = tanhFrac6:0.7615941595356353
# Value at 1.0 = tanhFrac7:0.7615941559343375
# Value at 1.0 = tanhFrac8:0.761594155955861
# Value at 1.0 = tanhFrac9:0.7615941559557645
# Value at 1.0 = tanhTaylor7:0.6803563892609054
# Value at 1.0 = tanhTaylor9:0.7292629376089544
# Value at 1.0 = tanhTaylor11:0.7534741377728573
# Value at 1.0 = tanhPate33:0.733351190421924
# Value at 1.0 = tanhPate34:0.7598424969717947
# Value at 1.0 = tanhPate44:0.7598424969717941
# Value at 1.0 = tanhPate45:0.7598424969717947
# Value at 1.0 = tanhPate55:0.7615805598777149

# %%
#Sigmoid Testing Values
range = -5.5:0.01:5.5

plot(range, sigmoid, label="sigmoid", legend=:topleft)
# Sigmoid Fitted Taylor
for f in FastActivations.SigmoidTaylorFunctions
    plot!(range, f, title="Taylor Fit Sigmoid", label="$(f)")
end
p = plot!()
savefig(p, "sigmoidtaylor.png")
p

# %%
plot(range, sigmoid, label="sigmoid", legend=:topleft)
# Sigmoid Fitted Pade
for f in FastActivations.SigmoidPadeFunctions
    plot!(range, f, title="Pade Fit Sigmoid", label="$(f)")
end
p = plot!()
savefig(p, "sigmoidpade.png")
p

# %%
plot(range, sigmoid, label="sigmoid", legend=:topleft)
# Sigmoid Mathematical
for f in FastActivations.SigmoidMathematicalFunctions
    plot!(range, f, title="Fast Exp Approximation Sigmoid", label="$(f)")
end
p = plot!()
savefig(p, "sigmoidfastexp.png")
p

# %%
#Sigmoid Testing Values
range = -5.5:0.01:5.5

plot(range, tanh, label="tanh", legend=:topleft)
# Tanh Fitted Pade
for f in FastActivations.TanhTaylorFunctions
    plot!(range, f, title="Taylor Fit Tanh",label="$(f)")
end
p = plot!()
savefig(p, "tanhtaylor.png")
p

# %%
plot(range, tanh, label="tanh", legend=:topleft)
# Tanh Fitted Pade
for f in FastActivations.TanhPadeFunctions
    plot!(range, f, title="Pade Fit Tanh",label="$(f)")
end
p = plot!()
savefig(p, "tanhpade.png")
p

# %%
plot(range, tanh, label="tanh", legend=:topleft)
# Tanh Cont. Frac
for f in FastActivations.TanhContinuousFunctions
    plot!(range, f, title="Continuous Fraction Tanh",label="$(f)")
end
p = plot!()
savefig(p, "tanhcontfrac.png")
p

# %%
plot(range, tanh, label="tanh", legend=:topleft)
# Tanh Cont. Frac Clamp
for f in FastActivations.TanhContinuousFunctions
    plot!(range, x -> FastActivations.tanhClamp(f,x), title="Clamp Cont. Frac Tanh",label="$(f)")
end
p = plot!()
savefig(p, "tanhclampcont.png")
p

# %%
plot(range, tanh, label="tanh", legend=:topleft)
# Tanh Serpentine
for f in FastActivations.TanhSerpentineFunctions
    plot!(range, f, title="Serpentine Tanh",label="$(f)")
end
p = plot!()
savefig(p, "tanhserpentine.png")
p
